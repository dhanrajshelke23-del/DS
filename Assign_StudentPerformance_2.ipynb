# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# 11        69.0           78.0           77.0               90            2020
# 12        80.0           88.0           77.0               77            2018
# 13        66.0           90.0           72.0               93            2020
# 14        64.0           90.0           67.0               79            2020
# 15        78.0           86.0           64.0               76            2019
# 16        61.0           95.0           64.0               75            2021
# 17       180.0           82.0           76.0               95            2019
# 18        80.0           90.0           74.0               81            2019
# 19        70.0           82.0            NaN               89            2020
# 20        69.0           83.0           74.0               77            2021
# 21        71.0           81.0           63.0               91            2020
# 22        71.0           91.0           61.0               75            2020
# 23        61.0           78.0           69.0               75            2020
# 24         NaN           81.0           66.0               81            2019
# 25        76.0           83.0           79.0               77            2019
# 26        68.0           87.0           76.0               95            2020
# 27        61.0           75.0           63.0               93            2020
# 28        80.0            NaN           61.0              100            2020
# 29        65.0           78.0           73.0               98            2018
#
#     Placement_Offer_Count
# 0                       2
# 1                       3
# 2                       3
# 3                       2
# 4                       3
# 5                       2
# 6                       3
# 7                       3
# 8                       2
# 9                       1
# 10                      2
# 11                      3
# 12                      2
# 13                      3
# 14                      2
# 15                      2
# 16                      2
# 17                      3
# 18                      2
# 19                      3
# 20                      2
# 21                      3
# 22                      2
# 23                      2
# 24                      2
# 25                      2
# 26                      3
# 27                      3
# 28                      3
# 29                      3

# %%
df.head()
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0        80.0           90.0           70.0               77            2018
# 1        70.0           77.0           76.0               85            2018
# 2        62.0           88.0           68.0               92            2019
# 3        94.0           84.0           71.0               78            2019
# 4        78.0           81.0           62.0              100            2020
#
#    Placement_Offer_Count
# 0                      2
# 1                      3
# 2                      3
# 3                      2
# 4                      3

# %%
df.shape
# Out:
# (30, 6)

# %%
df.isnull().head()
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0       False          False          False            False           False
# 1       False          False          False            False           False
# 2       False          False          False            False           False
# 3       False          False          False            False           False
# 4       False          False          False            False           False
#
#    Placement_Offer_Count
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %%
df.isnull().sum()
# Out:
# Math_score               1
# Reading_score            1
# Writing_score            1
# Placement_score          0
# Club_Join_Date           0
# Placement_Offer_Count    0
# dtype: int64

# %%
df.notnull()
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# 11        True           True           True             True            True
# 12        True           True           True             True            True
# 13        True           True           True             True            True
# 14        True           True           True             True            True
# 15        True           True           True             True            True
# 16        True           True           True             True            True
# 17        True           True           True             True            True
# 18        True           True           True             True            True
# 19        True           True          False             True            True
# 20        True           True           True             True            True
# 21        True           True           True             True            True
# 22        True           True           True             True            True
# 23        True           True           True             True            True
# 24       False           True           True             True            True
# 25        True           True           True             True            True
# 26        True           True           True             True            True
# 27        True           True           True             True            True
# 28        True          False           True             True            True
# 29        True           True           True             True            True
#
#     Placement_Offer_Count
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
# 5                    True
# 6                    True
# 7                    True
# 8                    True
# 9                    True
# 10                   True
# 11                   True
# 12                   True
# 13                   True
# 14                   True
# 15                   True
# 16                   True
# 17                   True
# 18                   True
# 19                   True
# 20                   True
# 21                   True
# 22                   True
# 23                   True
# 24                   True
# 25                   True
# 26                   True
# 27                   True
# 28                   True
# 29                   True

# %%
df.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score  \
# count   29.000000      29.000000      29.000000        30.000000
# mean    75.103448      88.068966      69.620690        85.633333
# std     21.699810      22.238851       5.734693         8.833648
# min     61.000000      75.000000      61.000000        75.000000
# 25%     65.000000      80.000000      64.000000        77.250000
# 50%     70.000000      83.000000      70.000000        82.000000
# 75%     78.000000      90.000000      74.000000        93.000000
# max    180.000000     200.000000      79.000000       100.000000
#
#        Club_Join_Date  Placement_Offer_Count
# count       30.000000              30.000000
# mean      2019.466667               2.433333
# std          0.899553               0.568321
# min       2018.000000               1.000000
# 25%       2019.000000               2.000000
# 50%       2020.000000               2.000000
# 75%       2020.000000               3.000000
# max       2021.000000               3.000000

# %%
df1 = df

# %%
df1.fillna(0)
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# 11        69.0           78.0           77.0               90            2020
# 12        80.0           88.0           77.0               77            2018
# 13        66.0           90.0           72.0               93            2020
# 14        64.0           90.0           67.0               79            2020
# 15        78.0           86.0           64.0               76            2019
# 16        61.0           95.0           64.0               75            2021
# 17       180.0           82.0           76.0               95            2019
# 18        80.0           90.0           74.0               81            2019
# 19        70.0           82.0            0.0               89            2020
# 20        69.0           83.0           74.0               77            2021
# 21        71.0           81.0           63.0               91            2020
# 22        71.0           91.0           61.0               75            2020
# 23        61.0           78.0           69.0               75            2020
# 24         0.0           81.0           66.0               81            2019
# 25        76.0           83.0           79.0               77            2019
# 26        68.0           87.0           76.0               95            2020
# 27        61.0           75.0           63.0               93            2020
# 28        80.0            0.0           61.0              100            2020
# 29        65.0           78.0           73.0               98            2018
#
#     Placement_Offer_Count
# 0                       2
# 1                       3
# 2                       3
# 3                       2
# 4                       3
# 5                       2
# 6                       3
# 7                       3
# 8                       2
# 9                       1
# 10                      2
# 11                      3
# 12                      2
# 13                      3
# 14                      2
# 15                      2
# 16                      2
# 17                      3
# 18                      2
# 19                      3
# 20                      2
# 21                      3
# 22                      2
# 23                      2
# 24                      2
# 25                      2
# 26                      3
# 27                      3
# 28                      3
# 29                      3

# %%
df2 = df

# %%
df2["Math_score"]=df2["Math_score"].fillna(df2["Math_score"].mean())

# %%
df2
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    80.000000           90.0           70.0               77            2018
# 1    70.000000           77.0           76.0               85            2018
# 2    62.000000           88.0           68.0               92            2019
# 3    94.000000           84.0           71.0               78            2019
# 4    78.000000           81.0           62.0              100            2020
# 5    77.000000          200.0           73.0               82            2020
# 6    77.000000           75.0           65.0              100            2020
# 7    62.000000           80.0           63.0               97            2019
# 8    79.000000           88.0           65.0               82            2018
# 9    63.000000           94.0           73.0               79            2021
# 10   66.000000           79.0           77.0               80            2019
# 11   69.000000           78.0           77.0               90            2020
# 12   80.000000           88.0           77.0               77            2018
# 13   66.000000           90.0           72.0               93            2020
# 14   64.000000           90.0           67.0               79            2020
# 15   78.000000           86.0           64.0               76            2019
# 16   61.000000           95.0           64.0               75            2021
# 17  180.000000           82.0           76.0               95            2019
# 18   80.000000           90.0           74.0               81            2019
# 19   70.000000           82.0            NaN               89            2020
# 20   69.000000           83.0           74.0               77            2021
# 21   71.000000           81.0           63.0               91            2020
# 22   71.000000           91.0           61.0               75            2020
# 23   61.000000           78.0           69.0               75            2020
# 24   75.103448           81.0           66.0               81            2019
# 25   76.000000           83.0           79.0               77            2019
# 26   68.000000           87.0           76.0               95            2020
# 27   61.000000           75.0           63.0               93            2020
# 28   80.000000            NaN           61.0              100            2020
# 29   65.000000           78.0           73.0               98            2018
#
#     Placement_Offer_Count
# 0                       2
# 1                       3
# 2                       3
# 3                       2
# 4                       3
# 5                       2
# 6                       3
# 7                       3
# 8                       2
# 9                       1
# 10                      2
# 11                      3
# 12                      2
# 13                      3
# 14                      2
# 15                      2
# 16                      2
# 17                      3
# 18                      2
# 19                      3
# 20                      2
# 21                      3
# 22                      2
# 23                      2
# 24                      2
# 25                      2
# 26                      3
# 27                      3
# 28                      3
# 29                      3

# %%
col=["Math_score","Reading_score","Writing_score","Placement_score"]

# %%
print(df.columns)
# Out:
# Index(['Math_score', 'Reading_score', 'Writing_score', 'Placement_score',
#        'Club_Join_Date', 'Placement_Offer_Count'],
#       dtype='object')

# %%
print(df[["Math_score","Reading_score","Writing_score","Placement_score"]].dtypes)
# Out:
# Math_score         float64
# Reading_score      float64
# Writing_score      float64
# Placement_score      int64
# dtype: object

# %%
df[col].dropna().boxplot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 df[col].dropna().boxplot()
#       2 plt.show()
#
# File ~\Annaconda1\Lib\site-packages\pandas\plotting\_core.py:507, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     490 @Substitution(data="", backend=_backend_doc)
#     491 @Appender(_boxplot_doc)
#     492 def boxplot_frame(
#    (...)
#     504     **kwargs,
#     505 ):
#     506     plot_backend = _get_plot_backend(backend)
# --> 507     return plot_backend.boxplot_frame(
#     508         self,
#     509         column=column,
#     510         by=by,
#     511         ax=ax,
#     512         fontsize=fontsize,
#     513         rot=rot,
#     514         grid=grid,
#     515         figsize=figsize,
#     516         layout=layout,
#     517         return_type=return_type,
#     518         **kwargs,
#     519     )
#
# File ~\Annaconda1\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:469, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     454 def boxplot_frame(
#     455     self,
#     456     column=None,
#    (...)
#     465     **kwds,
#     466 ):
#     467     import matplotlib.pyplot as plt
# --> 469     ax = boxplot(
#     470         self,
#     471         column=column,
#     472         by=by,
#     473         ax=ax,
#     474         fontsize=fontsize,
#     475         grid=grid,
#     476         rot=rot,
#     477         figsize=figsize,
#     478         layout=layout,
#     479         return_type=return_type,
#     480         **kwds,
#     481     )
#     482     plt.draw_if_interactive()
#     483     return ax
#
# File ~\Annaconda1\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:448, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     445     else:
#     446         data = data[columns]
# --> 448     result = plot_group(columns, data.values.T, ax, **kwds)
#     449     ax.grid(grid)
#     451 return result
#
# File ~\Annaconda1\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:387, in boxplot.<locals>.plot_group(keys, values, ax, **kwds)
#     385 if len(ticks) != len(keys):
#     386     i, remainder = divmod(len(ticks), len(keys))
# --> 387     assert remainder == 0, remainder
#     388     keys *= i
#     389 if is_vertical:
#
# AssertionError: 2

# %%
new_df=pd.read_csv("StudentsPerformance.csv")
new_df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# 11        69.0           78.0           77.0               90            2020
# 12        80.0           88.0           77.0               77            2018
# 13        66.0           90.0           72.0               93            2020
# 14        64.0           90.0           67.0               79            2020
# 15        78.0           86.0           64.0               76            2019
# 16        61.0           95.0           64.0               75            2021
# 17       180.0           82.0           76.0               95            2019
# 18        80.0           90.0           74.0               81            2019
# 19        70.0           82.0            NaN               89            2020
# 20        69.0           83.0           74.0               77            2021
# 21        71.0           81.0           63.0               91            2020
# 22        71.0           91.0           61.0               75            2020
# 23        61.0           78.0           69.0               75            2020
# 24         NaN           81.0           66.0               81            2019
# 25        76.0           83.0           79.0               77            2019
# 26        68.0           87.0           76.0               95            2020
# 27        61.0           75.0           63.0               93            2020
# 28        80.0            NaN           61.0              100            2020
# 29        65.0           78.0           73.0               98            2018
#
#     Placement_Offer_Count
# 0                       2
# 1                       3
# 2                       3
# 3                       2
# 4                       3
# 5                       2
# 6                       3
# 7                       3
# 8                       2
# 9                       1
# 10                      2
# 11                      3
# 12                      2
# 13                      3
# 14                      2
# 15                      2
# 16                      2
# 17                      3
# 18                      2
# 19                      3
# 20                      2
# 21                      3
# 22                      2
# 23                      2
# 24                      2
# 25                      2
# 26                      3
# 27                      3
# 28                      3
# 29                      3

# %%
print(np.where(new_df["Math_score"]>90))
# Out:
# (array([ 3, 17], dtype=int64),)

# %%
mean1=np.mean(df["Math_score"])
mean1
# Out:
# 75.10344827586208

# %%
z=stats.zscore(df['Math_score'])

# %%
z
# Out:
# 0     2.335694e-01
# 1    -2.434386e-01
# 2    -6.250450e-01
# 3     9.013807e-01
# 4     1.381678e-01
# 5     9.046704e-02
# 6     9.046704e-02
# 7    -6.250450e-01
# 8     1.858686e-01
# 9    -5.773442e-01
# 10   -4.342418e-01
# 11   -2.911394e-01
# 12    2.335694e-01
# 13   -4.342418e-01
# 14   -5.296434e-01
# 15    1.381678e-01
# 16   -6.727458e-01
# 17    5.003650e+00
# 18    2.335694e-01
# 19   -2.434386e-01
# 20   -2.911394e-01
# 21   -1.957378e-01
# 22   -1.957378e-01
# 23   -6.727458e-01
# 24   -6.778692e-16
# 25    4.276624e-02
# 26   -3.388402e-01
# 27   -6.727458e-01
# 28    2.335694e-01
# 29   -4.819426e-01
# Name: Math_score, dtype: float64

# %%
threshold=5

# %%
sample_outliers = np.where(z>threshold)
sample_outliers
# Out:
# (array([17], dtype=int64),)

# %%
Q1=df.Math_score.quantile(0.25)
Q1
# Out:
# 65.25

# %%
Q3=df.Math_score.quantile(0.75)

# %%
Q1
# Out:
# 65.25

# %%
Q3
# Out:
# 78.0

# %%
IQR = Q3 - Q1

# %%
IQR
# Out:
# 12.75

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (46.125, 97.125)

# %%
df[(df.Math_score<lower_limit)|(df.Math_score>upper_limit)]
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 17       180.0           82.0           76.0               95            2019
#
#     Placement_Offer_Count
# 17                      3

# %%
sample_outliers1=df["Math_score"][(df["Math_score"]>upper_limit)|(df["Math_score"]<lower_limit)]

# %%
sample_outliers1
# Out:
# 17    180.0
# Name: Math_score, dtype: float64

# %%
index_outliers=np.where((df.Math_score<lower_limit)|(df.Math_score>upper_limit))
index_outliers
# Out:
# (array([17], dtype=int64),)

# %%
redefined_df=df2
redefined_df['Math_score']=np.where((redefined_df['Math_score'] >upper_limit),mean1,redefined_df['Math_score'])

# %%
redefined_df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    80.000000           90.0           70.0               77            2018
# 1    70.000000           77.0           76.0               85            2018
# 2    62.000000           88.0           68.0               92            2019
# 3    94.000000           84.0           71.0               78            2019
# 4    78.000000           81.0           62.0              100            2020
# 5    77.000000          200.0           73.0               82            2020
# 6    77.000000           75.0           65.0              100            2020
# 7    62.000000           80.0           63.0               97            2019
# 8    79.000000           88.0           65.0               82            2018
# 9    63.000000           94.0           73.0               79            2021
# 10   66.000000           79.0           77.0               80            2019
# 11   69.000000           78.0           77.0               90            2020
# 12   80.000000           88.0           77.0               77            2018
# 13   66.000000           90.0           72.0               93            2020
# 14   64.000000           90.0           67.0               79            2020
# 15   78.000000           86.0           64.0               76            2019
# 16   61.000000           95.0           64.0               75            2021
# 17   75.103448           82.0           76.0               95            2019
# 18   80.000000           90.0           74.0               81            2019
# 19   70.000000           82.0            NaN               89            2020
# 20   69.000000           83.0           74.0               77            2021
# 21   71.000000           81.0           63.0               91            2020
# 22   71.000000           91.0           61.0               75            2020
# 23   61.000000           78.0           69.0               75            2020
# 24   75.103448           81.0           66.0               81            2019
# 25   76.000000           83.0           79.0               77            2019
# 26   68.000000           87.0           76.0               95            2020
# 27   61.000000           75.0           63.0               93            2020
# 28   80.000000            NaN           61.0              100            2020
# 29   65.000000           78.0           73.0               98            2018
#
#     Placement_Offer_Count
# 0                       2
# 1                       3
# 2                       3
# 3                       2
# 4                       3
# 5                       2
# 6                       3
# 7                       3
# 8                       2
# 9                       1
# 10                      2
# 11                      3
# 12                      2
# 13                      3
# 14                      2
# 15                      2
# 16                      2
# 17                      3
# 18                      2
# 19                      3
# 20                      2
# 21                      3
# 22                      2
# 23                      2
# 24                      2
# 25                      2
# 26                      3
# 27                      3
# 28                      3
# 29                      3

# %%
col1=['Math_score']

# %%
redefined_df.boxplot(col1)
plt.show()

# %%
redefined_df.plot(kind="bar")
# Out:
# <Axes: >

# %%
df_min_max_scaled=redefined_df.copy()
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column]= (df_min_max_scaled[column]-df_min_max_scaled[column].min())/(df_min_max_scaled[column]-df_min_max_scaled[column].max())
df_min_max_scaled
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    -1.357143      -0.136364      -1.000000        -0.086957            -0.0
# 1    -0.375000      -0.016260      -5.000000        -0.666667            -0.0
# 2    -0.031250      -0.116071      -0.636364        -2.125000            -0.5
# 3          inf      -0.077586      -1.250000        -0.136364            -0.5
# 4    -1.062500      -0.050420      -0.058824              inf            -2.0
# 5    -0.941176            inf      -2.000000        -0.388889            -2.0
# 6    -0.941176      -0.000000      -0.285714              inf            -2.0
# 7    -0.031250      -0.041667      -0.125000        -7.333333            -0.5
# 8    -1.200000      -0.116071      -0.285714        -0.388889            -0.0
# 9    -0.064516      -0.179245      -2.000000        -0.190476             inf
# 10   -0.178571      -0.033058      -8.000000        -0.250000            -0.5
# 11   -0.320000      -0.024590      -8.000000        -1.500000            -2.0
# 12   -1.357143      -0.116071      -8.000000        -0.086957            -0.0
# 13   -0.178571      -0.136364      -1.571429        -2.571429            -2.0
# 14   -0.100000      -0.136364      -0.500000        -0.190476            -2.0
# 15   -1.062500      -0.096491      -0.200000        -0.041667            -0.5
# 16   -0.000000      -0.190476      -0.200000        -0.000000             inf
# 17   -0.746350      -0.059322      -5.000000        -4.000000            -0.5
# 18   -1.357143      -0.136364      -2.600000        -0.315789            -0.5
# 19   -0.375000      -0.059322            NaN        -1.272727            -2.0
# 20   -0.320000      -0.068376      -2.600000        -0.086957             inf
# 21   -0.434783      -0.050420      -0.125000        -1.777778            -2.0
# 22   -0.434783      -0.146789      -0.000000        -0.000000            -2.0
# 23   -0.000000      -0.024590      -0.800000        -0.000000            -2.0
# 24   -0.746350      -0.050420      -0.384615        -0.315789            -0.5
# 25   -0.833333      -0.068376            inf        -0.086957            -0.5
# 26   -0.269231      -0.106195      -5.000000        -4.000000            -2.0
# 27   -0.000000      -0.000000      -0.125000        -2.571429            -2.0
# 28   -1.357143            NaN      -0.000000              inf            -2.0
# 29   -0.137931      -0.024590      -2.000000       -11.500000            -0.0
#
#     Placement_Offer_Count
# 0                    -1.0
# 1                     inf
# 2                     inf
# 3                    -1.0
# 4                     inf
# 5                    -1.0
# 6                     inf
# 7                     inf
# 8                    -1.0
# 9                    -0.0
# 10                   -1.0
# 11                    inf
# 12                   -1.0
# 13                    inf
# 14                   -1.0
# 15                   -1.0
# 16                   -1.0
# 17                    inf
# 18                   -1.0
# 19                    inf
# 20                   -1.0
# 21                    inf
# 22                   -1.0
# 23                   -1.0
# 24                   -1.0
# 25                   -1.0
# 26                    inf
# 27                    inf
# 28                    inf
# 29                    inf

# %%
df_min_max_scaled.plot(kind="bar")
# Out:
# <Axes: >

# %%
df_min_max_scaled.skew()
# Out:
# Math_score              NaN
# Reading_score           NaN
# Writing_score           NaN
# Placement_score         NaN
# Club_Join_Date          NaN
# Placement_Offer_Count   NaN
# dtype: float64

# %%
df_min_max_scaled.kurtosis()
# Out:
# Math_score              NaN
# Reading_score           NaN
# Writing_score           NaN
# Placement_score         NaN
# Club_Join_Date          NaN
# Placement_Offer_Count   NaN
# dtype: float64
