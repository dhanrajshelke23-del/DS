# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

df=pd.read_csv("Mall_Customers.csv")

# %%
df=pd.read_csv("Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
group = df.groupby('Age')['Annual Income (k$)'].agg(['mean', 'median', 'min', 'max', 'std'])
group
# Out:
#            mean  median  min  max        std
# Age
# 18    51.250000    53.5   33   65  14.056434
# 19    57.000000    63.5   15   81  20.632845
# 20    41.600000    37.0   16   73  24.815318
# 21    38.800000    33.0   15   62  19.018412
# 22    31.333333    20.0   17   57  22.278540
# 23    41.500000    41.5   16   70  23.441416
# 24    39.250000    38.5   20   60  16.357975
# 25    57.666667    72.0   24   77  29.263174
# 26    58.000000    58.0   54   62   5.656854
# 27    63.166667    63.5   40   88  18.400181
# 28    85.250000    82.0   76  101  11.615363
# 29    63.600000    73.0   28   98  28.866936
# 30    76.142857    78.0   19  137  39.612408
# 31    48.375000    41.5   17   81  23.323425
# 32    87.181818    77.0   48  137  26.809768
# 33    80.333333    86.0   42  113  35.837597
# 34    79.000000    78.0   58  103  15.968719
# 35    46.666667    24.0   18  120  38.632888
# 36    81.000000    87.0   37  103  22.556595
# 37    65.000000    78.0   20   97  40.112342
# ...

# %%
print('Summary statistics for Age grouped by Genre:')
df.groupby('Gender')['Age'].agg(['mean', 'median', 'min', 'max', 'std'])
# Out:
# Summary statistics for Age grouped by Genre:
#              mean  median  min  max        std
# Gender
# Female  38.098214    35.0   18   68  12.644095
# Male    39.806818    37.0   18   70  15.514812

# %%
print('summary statistics for age grouped by spending score:')
df.groupby('Age')['Spending Score (1-100)'].agg(['mean','median','min','max','std'])
# Out:
# summary statistics for age grouped by spending score:
#           mean  median  min  max        std
# Age
# 18   60.000000    53.5   41   92  22.583180
# 19   39.750000    48.0    5   59  20.851516
# 20   40.200000    49.0    5   75  33.025748
# 21   66.800000    73.0   42   81  16.976454
# 22   70.000000    76.0   55   79  13.076697
# 23   63.333333    64.5   29   94  26.432303
# 24   71.500000    71.0   52   92  17.058722
# 25   39.666667    34.0   12   73  30.892286
# 26   54.500000    54.5   54   55   0.707107
# 27   60.333333    53.5   47   89  16.045768
# 28   70.000000    71.5   40   97  23.508864
# 29   76.600000    83.0   42   88  19.539703
# 30   80.285714    78.0   72   97   9.123491
# 31   63.875000    66.0   40   93  18.161478
# 32   66.000000    73.0   18   93  22.374092
# 33   54.333333    60.0    8   95  43.775945
# 34   39.200000    23.0    1   90  35.464066
# 35   63.888889    72.0    6   99  32.405418
# 36   52.500000    51.0   10   92  35.444323
# ...

# %%
print('summary statistics for gender grouped by annual income:')
df.groupby('Gender')['Annual Income (k$)'].agg(['mean','median','min','max','std'])
# Out:
# summary statistics for gender grouped by annual income:
#              mean  median  min  max        std
# Gender
# Female  59.250000    60.0   16  126  26.011952
# Male    62.227273    62.5   15  137  26.638373

# %%
print('summary statistics for age grouped by annual income:')
df.groupby('Age')['Annual Income (k$)'].agg(['mean','median','min','max','std'])
# Out:
# summary statistics for age grouped by annual income:
#            mean  median  min  max        std
# Age
# 18    51.250000    53.5   33   65  14.056434
# 19    57.000000    63.5   15   81  20.632845
# 20    41.600000    37.0   16   73  24.815318
# 21    38.800000    33.0   15   62  19.018412
# 22    31.333333    20.0   17   57  22.278540
# 23    41.500000    41.5   16   70  23.441416
# 24    39.250000    38.5   20   60  16.357975
# 25    57.666667    72.0   24   77  29.263174
# 26    58.000000    58.0   54   62   5.656854
# 27    63.166667    63.5   40   88  18.400181
# 28    85.250000    82.0   76  101  11.615363
# 29    63.600000    73.0   28   98  28.866936
# 30    76.142857    78.0   19  137  39.612408
# 31    48.375000    41.5   17   81  23.323425
# 32    87.181818    77.0   48  137  26.809768
# 33    80.333333    86.0   42  113  35.837597
# 34    79.000000    78.0   58  103  15.968719
# 35    46.666667    24.0   18  120  38.632888
# ...

# %%
import pandas as pd
dr=pd.read_csv("iris.csv")

# %%
dr.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dr.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data = dr[dr['Species'] == 'Iris-setosa']

print(data.mean(numeric_only=True))
# Out:
# Id               25.500
# SepalLengthCm     5.006
# SepalWidthCm      3.418
# PetalLengthCm     1.464
# PetalWidthCm      0.244
# dtype: float64

# %%
data1 = dr[dr['Species'] == 'Iris-versicolor']

print(data1.mean(numeric_only=True))
# Out:
# Id               75.500
# SepalLengthCm     5.936
# SepalWidthCm      2.770
# PetalLengthCm     4.260
# PetalWidthCm      1.326
# dtype: float64

# %%
data2 = dr[dr['Species'] == 'Iris-virginica']

print(data2.mean(numeric_only=True))
# Out:
# Id               125.500
# SepalLengthCm      6.588
# SepalWidthCm       2.974
# PetalLengthCm      5.552
# PetalWidthCm       2.026
# dtype: float64

# %%
dr.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.quantile(0.25,numeric_only=True)
# Out:
# Id               63.250
# SepalLengthCm     5.600
# SepalWidthCm      2.525
# PetalLengthCm     4.000
# PetalWidthCm      1.200
# Name: 0.25, dtype: float64

# %%
data.quantile(0.50,numeric_only=True)
# Out:
# Id               75.50
# SepalLengthCm     5.90
# SepalWidthCm      2.80
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# Name: 0.5, dtype: float64

# %%
data.quantile(0.75,numeric_only=True)
# Out:
# Id               87.75
# SepalLengthCm     6.30
# SepalWidthCm      3.00
# PetalLengthCm     4.60
# PetalWidthCm      1.50
# Name: 0.75, dtype: float64

# %%
data.std(numeric_only=True)
# Out:
# Id               14.577380
# SepalLengthCm     0.516171
# SepalWidthCm      0.313798
# PetalLengthCm     0.469911
# PetalWidthCm      0.197753
# dtype: float64

# %%
data1.std(numeric_only=True)
# Out:
# Id               14.577380
# SepalLengthCm     0.516171
# SepalWidthCm      0.313798
# PetalLengthCm     0.469911
# PetalWidthCm      0.197753
# dtype: float64

# %%
data2.std(numeric_only=True)
# Out:
# Id               14.577380
# SepalLengthCm     0.635880
# SepalWidthCm      0.322497
# PetalLengthCm     0.551895
# PetalWidthCm      0.274650
# dtype: float64
