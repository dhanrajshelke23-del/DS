# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("StudentsPerformance.csv");

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
df.head()
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0        80.0           90.0           70.0               77            2018
# 1        70.0           77.0           76.0               85            2018
# 2        62.0           88.0           68.0               92            2019
# 3        94.0           84.0           71.0               78            2019
# 4        78.0           81.0           62.0              100            2020
#
#    Placement_Offer_Count
# 0                      2
# 1                      3
# 2                      3
# 3                      2
# 4                      3

# %%
df.tail()
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 25        76.0           83.0           79.0               77            2019
# 26        68.0           87.0           76.0               95            2020
# 27        61.0           75.0           63.0               93            2020
# 28        80.0            NaN           61.0              100            2020
# 29        65.0           78.0           73.0               98            2018
#
#     Placement_Offer_Count
# 25                      2
# 26                      3
# 27                      3
# 28                      3
# 29                      3

# %%
df.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
df.columns
# Out:
# Index(['Math_score', 'Reading_score', 'Writing_score', 'Placement_score',
#        'Club_Join_Date', 'Placement_Offer_Count'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 6)

# %%
df.dtypes
# Out:
# Math_score               float64
# Reading_score            float64
# Writing_score            float64
# Placement_score            int64
# Club_Join_Date             int64
# Placement_Offer_Count      int64
# dtype: object

# %%
df.columns.values
# Out:
# array(['Math_score', 'Reading_score', 'Writing_score', 'Placement_score',
#        'Club_Join_Date', 'Placement_Offer_Count'], dtype=object)

# %%
df.columns.values.tolist()
# Out:
# ['Math_score',
#  'Reading_score',
#  'Writing_score',
#  'Placement_score',
#  'Club_Join_Date',
#  'Placement_Offer_Count']

# %%
df['Math_score']
# Out:
# 0      80.0
# 1      70.0
# 2      62.0
# 3      94.0
# 4      78.0
# 5      77.0
# 6      77.0
# 7      62.0
# 8      79.0
# 9      63.0
# 10     66.0
# 11     69.0
# 12     80.0
# 13     66.0
# 14     64.0
# 15     78.0
# 16     61.0
# 17    180.0
# 18     80.0
# 19     70.0
# 20     69.0
# 21     71.0
# 22     71.0
# 23     61.0
# 24      NaN
# 25     76.0
# 26     68.0
# 27     61.0
# 28     80.0
# 29     65.0
# Name: Math_score, dtype: float64

# %%
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
df.T
# Out:
#                            0       1       2       3       4       5       6   \
# Math_score               80.0    70.0    62.0    94.0    78.0    77.0    77.0
# Reading_score            90.0    77.0    88.0    84.0    81.0   200.0    75.0
# Writing_score            70.0    76.0    68.0    71.0    62.0    73.0    65.0
# Placement_score          77.0    85.0    92.0    78.0   100.0    82.0   100.0
# Club_Join_Date         2018.0  2018.0  2019.0  2019.0  2020.0  2020.0  2020.0
# Placement_Offer_Count     2.0     3.0     3.0     2.0     3.0     2.0     3.0
#
#                            7       8       9   ...      20      21      22  \
# Math_score               62.0    79.0    63.0  ...    69.0    71.0    71.0
# Reading_score            80.0    88.0    94.0  ...    83.0    81.0    91.0
# Writing_score            63.0    65.0    73.0  ...    74.0    63.0    61.0
# Placement_score          97.0    82.0    79.0  ...    77.0    91.0    75.0
# ...

# %%
df.sort_index(axis = 1 , ascending = True)
# Out:
#     Club_Join_Date  Math_score  Placement_Offer_Count  Placement_score  \
# 0             2018        80.0                      2               77
# 1             2018        70.0                      3               85
# 2             2019        62.0                      3               92
# 3             2019        94.0                      2               78
# 4             2020        78.0                      3              100
# 5             2020        77.0                      2               82
# 6             2020        77.0                      3              100
# 7             2019        62.0                      3               97
# 8             2018        79.0                      2               82
# 9             2021        63.0                      1               79
# 10            2019        66.0                      2               80
# 11            2020        69.0                      3               90
# ...

# %%
df.sort_index(axis = 0 , ascending = False)
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 29        65.0           78.0           73.0               98            2018
# 28        80.0            NaN           61.0              100            2020
# 27        61.0           75.0           63.0               93            2020
# 26        68.0           87.0           76.0               95            2020
# 25        76.0           83.0           79.0               77            2019
# 24         NaN           81.0           66.0               81            2019
# 23        61.0           78.0           69.0               75            2020
# 22        71.0           91.0           61.0               75            2020
# 21        71.0           81.0           63.0               91            2020
# 20        69.0           83.0           74.0               77            2021
# 19        70.0           82.0            NaN               89            2020
# ...

# %%
df.sort_values(by="Club_Join_Date")
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 12        80.0           88.0           77.0               77            2018
# 8         79.0           88.0           65.0               82            2018
# 29        65.0           78.0           73.0               98            2018
# 1         70.0           77.0           76.0               85            2018
# 7         62.0           80.0           63.0               97            2019
# 2         62.0           88.0           68.0               92            2019
# 25        76.0           83.0           79.0               77            2019
# 10        66.0           79.0           77.0               80            2019
# 24         NaN           81.0           66.0               81            2019
# 15        78.0           86.0           64.0               76            2019
# ...

# %%
df.isnull()
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
df.notnull()
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.notnull().sum()
# Out:
# Math_score               29
# Reading_score            29
# Writing_score            29
# Placement_score          30
# Club_Join_Date           30
# Placement_Offer_Count    30
# dtype: int64

# %%
df.iloc[5]
# Out:
# Math_score                 77.0
# Reading_score             200.0
# Writing_score              73.0
# Placement_score            82.0
# Club_Join_Date           2020.0
# Placement_Offer_Count       2.0
# Name: 5, dtype: float64

# %%
df.iloc[2]
# Out:
# Math_score                 62.0
# Reading_score              88.0
# Writing_score              68.0
# Placement_score            92.0
# Club_Join_Date           2019.0
# Placement_Offer_Count       3.0
# Name: 2, dtype: float64

# %%
df.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score  \
# count   29.000000      29.000000      29.000000        30.000000
# mean    75.103448      88.068966      69.620690        85.633333
# std     21.699810      22.238851       5.734693         8.833648
# min     61.000000      75.000000      61.000000        75.000000
# 25%     65.000000      80.000000      64.000000        77.250000
# 50%     70.000000      83.000000      70.000000        82.000000
# 75%     78.000000      90.000000      74.000000        93.000000
# max    180.000000     200.000000      79.000000       100.000000
#
#        Club_Join_Date  Placement_Offer_Count
# count       30.000000              30.000000
# mean      2019.466667               2.433333
# std          0.899553               0.568321
# min       2018.000000               1.000000
# 25%       2019.000000               2.000000
# 50%       2020.000000               2.000000
# 75%       2020.000000               3.000000
# ...

# %%
df.fillna(0)
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
df.mean()
# Out:
# Math_score                 75.103448
# Reading_score              88.068966
# Writing_score              69.620690
# Placement_score            85.633333
# Club_Join_Date           2019.466667
# Placement_Offer_Count       2.433333
# dtype: float64

# %%
df.median()
# Out:
# Math_score                 70.0
# Reading_score              83.0
# Writing_score              70.0
# Placement_score            82.0
# Club_Join_Date           2020.0
# Placement_Offer_Count       2.0
# dtype: float64

# %%
df.mode()
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0        80.0           90.0           63.0             77.0          2020.0
# 1         NaN            NaN           73.0              NaN             NaN
# 2         NaN            NaN           76.0              NaN             NaN
# 3         NaN            NaN           77.0              NaN             NaN
#
#    Placement_Offer_Count
# 0                    2.0
# 1                    NaN
# 2                    NaN
# 3                    NaN

# %%
df.head()
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0        80.0           90.0           70.0               77            2018
# 1        70.0           77.0           76.0               85            2018
# 2        62.0           88.0           68.0               92            2019
# 3        94.0           84.0           71.0               78            2019
# 4        78.0           81.0           62.0              100            2020
#
#    Placement_Offer_Count
# 0                      2
# 1                      3
# 2                      3
# 3                      2
# 4                      3

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...
